# %% [markdown]
# # Sensitive Data Classification
#
# ## Importing libraries and downloading the dataset

# %%
# Importing the necessary libraries
import tensorflow as tf
import numpy as np
import os

# Downloading the dataset
git_folder = "/content/SPECIAL-TOPICS-67"
if os.path.exists(git_folder) == False:
  # !git clone https://github.com/manjuv03/SPECIAL-TOPICS-67.git # cloning the github repository

training_folder = git_folder + "/dataset/training"
validation_folder = git_folder + "/dataset/validation"
# Out:
# Cloning into 'SPECIAL-TOPICS-67'...
# remote: Enumerating objects: 711, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 711 (delta 0), reused 6 (delta 0), pack-reused 705
# Receiving objects: 100% (711/711), 78.76 MiB | 9.49 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %% [markdown]
# ## Sample Data

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

train_sensitive_dir = os.path.join(training_folder+"/sensitive")
train_nonsensitive_dir = os.path.join(training_folder+"/nonsensitive")
train_sensitive_names = os.listdir(train_sensitive_dir)
train_nonsensitive_names = os.listdir(train_nonsensitive_dir)

pic_index += 8
next_sensitive_pix = [os.path.join(train_sensitive_dir, fname) 
                for fname in train_sensitive_names[pic_index-8:pic_index]]
next_nonsensitive_pix = [os.path.join(train_nonsensitive_dir, fname) 
                for fname in train_nonsensitive_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_sensitive_pix+next_nonsensitive_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Model

# %%
# Callbacks to cancel training after reaching a desired accuracy
# This is done to avoid overfitting
DESIRED_ACCURACY = 0.98

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('accuracy') > DESIRED_ACCURACY:
      print("Reached 98% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# Sequential - defines a SEQUENCE of layers in the neural network.
model = tf.keras.models.Sequential([
  # 2D Convolution Layer - Filter, Kernel_size, activation fn
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
  # Max pooling operation for 2D data - Pool size
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # Flattens the input. Does not affect the batch size.
  tf.keras.layers.Flatten(),
  # Regular densely-connected Neural Network layer with ReLU activation function.
  tf.keras.layers.Dense(512, activation='relu'),
  # Regular densely-connected Neural Network layer with sigmoid activation function.
  tf.keras.layers.Dense(1, activation='sigmoid')
])

from tensorflow.keras.optimizers import RMSprop

# model.compile - Configures the model for training.
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Adam -  optimization algorithm used instead of the classical stochastic gradient descent procedure to update network weights.

# Display the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,969
# Trainable params: 6,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Preprocessing, Data Augmentation & Training

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescaling - 1/255 is to transform every pixel value from range [0,255] -> [0,1]
# Performing image augmentation for training data
train_datagen = ImageDataGenerator(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# flow_from_directory - Takes the path to a directory & generates batches of data.
train_generator = train_datagen.flow_from_directory(
        training_folder,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        validation_folder,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )

num_epochs = 500
# model.fit - Train the model for a fixed number of epochs
history = model.fit(
      train_generator,
      steps_per_epoch=10,
      epochs=num_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# 10/10 [==============================] - 18s 376ms/step - loss: 0.8001 - accuracy: 0.5433 - val_loss: 0.5658 - val_accuracy: 0.8000
# Epoch 2/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.5736 - accuracy: 0.7267 - val_loss: 0.4933 - val_accuracy: 0.8250
# Epoch 3/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.5390 - accuracy: 0.7700 - val_loss: 0.3838 - val_accuracy: 0.8000
# Epoch 4/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.5439 - accuracy: 0.6767 - val_loss: 0.4722 - val_accuracy: 0.8000
# Epoch 5/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.5405 - accuracy: 0.7300 - val_loss: 0.3720 - val_accuracy: 0.8500
# Epoch 6/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.4761 - accuracy: 0.7767 - val_loss: 0.4805 - val_accuracy: 0.7500
# Epoch 7/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.4538 - accuracy: 0.8000 - val_loss: 0.2676 - val_accuracy: 0.9500
# Epoch 8/500
# 10/10 [==============================] - 4s 404ms/step - loss: 0.4368 - accuracy: 0.8133 - val_loss: 0.3438 - val_accuracy: 0.8500
# Epoch 9/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.3962 - accuracy: 0.8467 - val_loss: 0.2175 - val_accuracy: 0.9000
# Epoch 10/500
# 10/10 [==============================] - 5s 480ms/step - loss: 0.3928 - accuracy: 0.8267 - val_loss: 0.2370 - val_accuracy: 0.9500
# Epoch 11/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4065 - accuracy: 0.8167 - val_loss: 0.2392 - val_accuracy: 0.9000
# Epoch 12/500
# 10/10 [==============================] - 4s 401ms/step - loss: 0.4677 - accuracy: 0.7800 - val_loss: 0.6331 - val_accuracy: 0.6500
# Epoch 13/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.4515 - accuracy: 0.7967 - val_loss: 0.2913 - val_accuracy: 0.9000
# Epoch 14/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.5059 - accuracy: 0.7700 - val_loss: 0.3828 - val_accuracy: 0.9250
# Epoch 15/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.4053 - accuracy: 0.8167 - val_loss: 0.1455 - val_accuracy: 0.9750
# Epoch 16/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.4030 - accuracy: 0.8333 - val_loss: 0.2143 - val_accuracy: 0.9000
# Epoch 17/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.3510 - accuracy: 0.8467 - val_loss: 0.0960 - val_accuracy: 0.9750
# Epoch 18/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.3406 - accuracy: 0.8467 - val_loss: 0.2510 - val_accuracy: 0.9000
# Epoch 19/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.3709 - accuracy: 0.8400 - val_loss: 0.1531 - val_accuracy: 0.9500
# Epoch 20/500
# 10/10 [==============================] - 4s 400ms/step - loss: 0.3801 - accuracy: 0.8333 - val_loss: 0.3213 - val_accuracy: 0.8500
# Epoch 21/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.3611 - accuracy: 0.8600 - val_loss: 0.1545 - val_accuracy: 0.9500
# Epoch 22/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.3701 - accuracy: 0.8333 - val_loss: 0.1702 - val_accuracy: 0.9500
# Epoch 23/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.3329 - accuracy: 0.8400 - val_loss: 0.4780 - val_accuracy: 0.7750
# Epoch 24/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.4325 - accuracy: 0.7933 - val_loss: 0.1936 - val_accuracy: 0.9750
# Epoch 25/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.3383 - accuracy: 0.8633 - val_loss: 0.1413 - val_accuracy: 0.9250
# Epoch 26/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.3420 - accuracy: 0.8333 - val_loss: 0.1374 - val_accuracy: 0.9750
# Epoch 27/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.3138 - accuracy: 0.8733 - val_loss: 0.1782 - val_accuracy: 0.9500
# Epoch 28/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.3165 - accuracy: 0.8500 - val_loss: 0.2377 - val_accuracy: 0.9250
# Epoch 29/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0
500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1774 - accuracy: 0.9433 - val_loss: 0.1124 - val_accuracy: 0.9500
# Epoch 58/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2685 - accuracy: 0.8967 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 59/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1861 - accuracy: 0.9400 - val_loss: 0.0343 - val_accuracy: 0.9750
# Epoch 60/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.2997 - accuracy: 0.9000 - val_loss: 0.1382 - val_accuracy: 0.9500
# Epoch 61/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.2970 - accuracy: 0.8867 - val_loss: 0.0769 - val_accuracy: 1.0000
# Epoch 62/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1947 - accuracy: 0.9200 - val_loss: 0.1044 - val_accuracy: 0.9500
# Epoch 63/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.1808 - accuracy: 0.9333 - val_loss: 0.1862 - val_accuracy: 0.9250
# Epoch 64/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1897 - accuracy: 0.9167 - val_loss: 0.2547 - val_accuracy: 0.8750
# Epoch 65/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.2105 - accuracy: 0.9400 - val_loss: 0.0899 - val_accuracy: 0.9750
# Epoch 66/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.1789 - accuracy: 0.9133 - val_loss: 0.1685 - val_accuracy: 0.9750
# Epoch 67/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1963 - accuracy: 0.9200 - val_loss: 0.1071 - val_accuracy: 0.9750
# Epoch 68/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1484 - accuracy: 0.9400 - val_loss: 0.0394 - val_accuracy: 0.9750
# Epoch 69/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1400 - accuracy: 0.9600 - val_loss: 0.0995 - val_accuracy: 0.9250
# Epoch 70/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.2045 - accuracy: 0.9167 - val_loss: 0.0677 - val_accuracy: 0.9750
# Epoch 71/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.2231 - accuracy: 0.9167 - val_loss: 0.0577 - val_accuracy: 0.9750
# Epoch 72/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1354 - accuracy: 0.9367 - val_loss: 0.0686 - val_accuracy: 0.9750
# Epoch 73/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.1062 - accuracy: 0.9500 - val_loss: 0.0994 - val_accuracy: 0.9750
# Epoch 74/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2065 - accuracy: 0.9133 - val_loss: 0.3666 - val_accuracy: 0.9000
# Epoch 75/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.2158 - accuracy: 0.9267 - val_loss: 0.0749 - val_accuracy: 0.9750
# Epoch 76/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1462 - accuracy: 0.9533 - val_loss: 0.0463 - val_accuracy: 0.9750
# Epoch 77/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1575 - accuracy: 0.9233 - val_loss: 0.1393 - val_accuracy: 0.9500
# Epoch 78/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1771 - accuracy: 0.9300 - val_loss: 0.0245 - val_accuracy: 1.0000
# Epoch 79/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.1552 - accuracy: 0.9333 - val_loss: 0.0496 - val_accuracy: 0.9750
# Epoch 80/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1877 - accuracy: 0.9300 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 81/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1326 - accuracy: 0.9433 - val_loss: 0.1397 - val_accuracy: 0.9250
# Epoch 82/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.1411 - accuracy: 0.9467 - val_loss: 0.1978 - val_accuracy: 0.9250
# Epoch 83/500
# 10/10 [==============================] - 4s 393ms/step - loss: 0.1980 - accuracy: 0.9300 - val_loss: 0.1302 - val_accuracy: 0.9500
# Epoch 84/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.1795 - accuracy: 0.9367 - val_loss: 0.0718 - val_accuracy: 0.9750
# Epoch 85/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1903 - accuracy: 0.9367 - val_loss: 0.0883 - val_accuracy: 0.9750
# Epoch 86/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.1339 - accuracy: 0.9500 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1007 - accuracy: 0.9700 - val_loss: 0.3017 - val_accuracy: 0.9500
# Epoch 136/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1028 - accuracy: 0.9633 - val_loss: 0.1878 - val_accuracy: 0.9250
# Epoch 137/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1040 - accuracy: 0.9600 - val_loss: 0.0496 - val_accuracy: 0.9750
# Epoch 138/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1275 - accuracy: 0.9467 - val_loss: 0.0661 - val_accuracy: 0.9750
# Epoch 139/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1429 - accuracy: 0.9633 - val_loss: 0.0839 - val_accuracy: 0.9750
# Epoch 140/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1593 - accuracy: 0.9367 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 141/500
# 10/10 [==============================] - 4s 437ms/step - loss: 0.1022 - accuracy: 0.9567 - val_loss: 0.1375 - val_accuracy: 0.9250
# Epoch 142/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1095 - accuracy: 0.9667 - val_loss: 0.0667 - val_accuracy: 0.9750
# Epoch 143/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9800Reached 98% accuracy so cancelling training!
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0588 - accuracy: 0.9800 - val_loss: 0.0575 - val_accuracy: 0.9750

# %% [markdown]
# ## Plotting Accuracy and Loss Functions

# %%
import matplotlib.pyplot as plt

# Plot the accuracy and loss functions
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn
y_pred = model.predict(validation_generator, 20)
print('Confusion Matrix')
y_predicted_labels = y_pred > 0.5

size = np.size(y_predicted_labels)
y_predicted_labels = y_predicted_labels.reshape(size, )

for i in range (1, 5):
  total = i * size // 4
  mid = 49
  start = mid-((total+1)//2)+1
  end = mid+((total+1)//2)
  cm = tf.math.confusion_matrix(labels=validation_generator.labels[start:end],predictions=y_predicted_labels[start:end])

  # Calculate accuracy
  cm_np = cm.numpy()
  conf_acc = (cm_np[0, 0] + cm_np[1, 1])/ np.sum(cm_np) * 100
  print("Accuracy for", str(total), "Test Data = ", conf_acc)

  # Plot the confusion matrix
  plt.figure(figsize = (10,7))
  seaborn.heatmap(cm, annot=True, fmt='d')
  plt.title("Confusion Matrix for " + str(total) + " Test Data")
  plt.xlabel('Predicted')
  plt.ylabel('Expected')
# Out:
# Confusion Matrix
# Accuracy for 25 Test Data =  20.0
# Accuracy for 50 Test Data =  30.612244897959183
# Accuracy for 75 Test Data =  32.0
# Accuracy for 100 Test Data =  38.38383838383838

# %% [markdown]
# ## Sample Example

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()
result = dict()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " - Sensitive")
    result[fn] = "Sensitive"
  else:
    print(fn + " - Non-sensitive")
    result[fn] = "Non-sensitive"

plt.figure(figsize=(20,20))
   
for i, fn in enumerate(uploaded.keys()):
  image = plt.imread(fn)  
  plt.subplot(5, 5, i+1)
  plt.axis("off")
  plt.imshow(image)
  ans = fn + ": " + result[fn]
  plt.title(ans)
# Out:
#      <input type="file" id="files-08743c43-f367-47e9-9533-7bbedb3e4886" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08743c43-f367-47e9-9533-7bbedb3e4886">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1 (49).jpg to 1 (49).jpg
# [5.705224e-38]
# 1 (49).jpg - Non-sensitive
