# %% [markdown]
# # Sensitive Data Classification Using Deep Learning
#
# # Importing libraries and downloading the dataset

# %%
# Importing the necessary libraries
import tensorflow as tf
import numpy as np
import os

# Downloading the dataset
git_folder = "/content/SPECIAL-TOPICS-67"
if os.path.exists(git_folder) == False:
  # !git clone https://github.com/manjuv03/SPECIAL-TOPICS-67

training_folder = git_folder + "/dataset/training"
validation_folder = git_folder + "/dataset/validation"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\MANJU SWAROOP V\OneDrive\Desktop\67 - SPECIAL TOPICS\Sensitive_Data_Classification.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/MANJU%20SWAROOP%20V/OneDrive/Desktop/67%20-%20SPECIAL%20TOPICS/Sensitive_Data_Classification.ipynb#ch0000001?line=0'>1</a> # Importing the necessary libraries
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MANJU%20SWAROOP%20V/OneDrive/Desktop/67%20-%20SPECIAL%20TOPICS/Sensitive_Data_Classification.ipynb#ch0000001?line=1'>2</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/c%3A/Users/MANJU%20SWAROOP%20V/OneDrive/Desktop/67%20-%20SPECIAL%20TOPICS/Sensitive_Data_Classification.ipynb#ch0000001?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/MANJU%20SWAROOP%20V/OneDrive/Desktop/67%20-%20SPECIAL%20TOPICS/Sensitive_Data_Classification.ipynb#ch0000001?line=3'>4</a> import os
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## Sample Data

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

train_sensitive_dir = os.path.join(training_folder+"/sensitive")
train_nonsensitive_dir = os.path.join(training_folder+"/nonsensitive")
train_sensitive_names = os.listdir(train_sensitive_dir)
train_nonsensitive_names = os.listdir(train_nonsensitive_dir)

pic_index += 8
next_sensitive_pix = [os.path.join(train_sensitive_dir, fname) 
                for fname in train_sensitive_names[pic_index-8:pic_index]]
next_nonsensitive_pix = [os.path.join(train_nonsensitive_dir, fname) 
                for fname in train_nonsensitive_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_sensitive_pix+next_nonsensitive_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Model

# %%
# Callbacks to cancel training after reaching a desired accuracy
# This is done to avoid overfitting
DESIRED_ACCURACY = 0.98

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('accuracy') > DESIRED_ACCURACY:
      print("Reached 98% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# Sequential - defines a SEQUENCE of layers in the neural network.
model = tf.keras.models.Sequential([
  # 2D Convolution Layer - Filter, Kernel_size, activation fn
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
  # Max pooling operation for 2D data - Pool size
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # Flattens the input. Does not affect the batch size.
  tf.keras.layers.Flatten(),
  # Regular densely-connected Neural Network layer with ReLU activation function.
  tf.keras.layers.Dense(512, activation='relu'),
  # Regular densely-connected Neural Network layer with sigmoid activation function.
  tf.keras.layers.Dense(1, activation='sigmoid')
])

from tensorflow.keras.optimizers import RMSprop

# model.compile - Configures the model for training.
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Adam -  optimization algorithm used instead of the classical stochastic gradient descent procedure to update network weights.

# Display the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,969
# Trainable params: 6,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Preprocessing, Data Augmentation & Training

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescaling - 1/255 is to transform every pixel value from range [0,255] -> [0,1]
# Performing image augmentation for training data
train_datagen = ImageDataGenerator(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# flow_from_directory - Takes the path to a directory & generates batches of data.
train_generator = train_datagen.flow_from_directory(
        training_folder,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        validation_folder,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )

num_epochs = 500
# model.fit - Train the model for a fixed number of epochs
history = model.fit(
      train_generator,
      steps_per_epoch=10,
      epochs=num_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# 10/10 [==============================] - 15s 360ms/step - loss: 0.7869 - accuracy: 0.5933 - val_loss: 0.5461 - val_accuracy: 0.7000
# Epoch 2/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.5833 - accuracy: 0.6933 - val_loss: 0.6083 - val_accuracy: 0.6500
# Epoch 3/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.5806 - accuracy: 0.7067 - val_loss: 0.4573 - val_accuracy: 0.8750
# Epoch 4/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.5319 - accuracy: 0.7533 - val_loss: 0.3689 - val_accuracy: 0.9000
# Epoch 5/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.4672 - accuracy: 0.7700 - val_loss: 0.3506 - val_accuracy: 0.8500
# Epoch 6/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.4858 - accuracy: 0.7800 - val_loss: 0.3619 - val_accuracy: 0.8250
# Epoch 7/500
# 10/10 [==============================] - 5s 475ms/step - loss: 0.4732 - accuracy: 0.7833 - val_loss: 0.3544 - val_accuracy: 0.9000
# Epoch 8/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.4542 - accuracy: 0.7900 - val_loss: 0.2750 - val_accuracy: 0.8750
# Epoch 9/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.4721 - accuracy: 0.7433 - val_loss: 0.3468 - val_accuracy: 0.9000
# Epoch 10/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.4427 - accuracy: 0.7967 - val_loss: 0.3331 - val_accuracy: 0.8500
# Epoch 11/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.4896 - accuracy: 0.7933 - val_loss: 0.4342 - val_accuracy: 0.8000
# Epoch 12/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.4561 - accuracy: 0.8100 - val_loss: 0.1823 - val_accuracy: 1.0000
# Epoch 13/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.5001 - accuracy: 0.7567 - val_loss: 0.3791 - val_accuracy: 0.8250
# Epoch 14/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.3883 - accuracy: 0.8300 - val_loss: 0.2896 - val_accuracy: 0.8750
# Epoch 15/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.4079 - accuracy: 0.8033 - val_loss: 0.2647 - val_accuracy: 0.8500
# Epoch 16/500
# 10/10 [==============================] - 4s 396ms/step - loss: 0.3949 - accuracy: 0.8167 - val_loss: 0.1884 - val_accuracy: 0.9250
# Epoch 17/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.3838 - accuracy: 0.8467 - val_loss: 0.1691 - val_accuracy: 0.9500
# Epoch 18/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.3678 - accuracy: 0.8500 - val_loss: 0.2447 - val_accuracy: 0.9250
# Epoch 19/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.3356 - accuracy: 0.8567 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 20/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.3431 - accuracy: 0.8533 - val_loss: 0.1167 - val_accuracy: 0.9750
# Epoch 21/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.3968 - accuracy: 0.8367 - val_loss: 0.2124 - val_accuracy: 0.9250
# Epoch 22/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.3693 - accuracy: 0.8367 - val_loss: 0.1631 - val_accuracy: 0.9500
# Epoch 23/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.3633 - accuracy: 0.8500 - val_loss: 0.1506 - val_accuracy: 0.9750
# Epoch 24/500
# 10/10 [==============================] - 4s 413ms/step - loss: 0.3132 - accuracy: 0.8467 - val_loss: 0.1491 - val_accuracy: 0.9750
# Epoch 25/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.3215 - accuracy: 0.8400 - val_loss: 0.1423 - val_accuracy: 0.9500
# Epoch 26/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.3534 - accuracy: 0.8433 - val_loss: 0.2764 - val_accuracy: 0.9250
# Epoch 27/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.2998 - accuracy: 0.8733 - val_loss: 0.0504 - val_accuracy: 0.9750
# Epoch 28/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.2606 - accuracy: 0.8933 - val_loss: 0.1406 - val_accuracy: 0.9750
# Epoch 29/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.2707 - accuracy: 0.9000 - val_loss: 0.0684 - val_accuracy: 0.9750
# Epoch 30/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.2661 - accuracy: 0.9067 - val_loss: 0.1634 - val_accuracy: 0.9250
# Epoch 31/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.2955 - accuracy: 0.8700 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 32/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.2657 - accuracy: 0.8967 - val_loss: 0.0403 - val_accuracy: 0.9750
# Epoch 33/500
# 10/10 [==============================] - 4s 396ms/step - loss: 0.3106 - accuracy: 0.8533 - val_loss: 0.1050 - val_accuracy: 0.9750
# Epoch 34/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2862 - accuracy: 0.8900 - val_loss: 0.0879 - val_accuracy: 0.9750
# Epoch 35/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.2929 - accuracy: 0.8833 - val_loss: 0.1153 - val_accuracy: 0.9750
# Epoch 36/500
# 10/10 [==============================] - 4s 394ms/step - loss: 0.2398 - accuracy: 0.9033 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 37/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.2926 - accuracy: 0.8667 - val_loss: 0.1169 - val_accuracy: 0.9500
# Epoch 38/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.2318 - accuracy: 0.9133 - val_loss: 0.2732 - val_accuracy: 0.8750
# Epoch 39/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.2179 - accuracy: 0.9267 - val_loss: 0.1154 - val_accuracy: 0.9750
# Epoch 40/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.2545 - accuracy: 0.9000 - val_loss: 0.1079 - val_accuracy: 0.9500
# Epoch 41/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.2663 - accuracy: 0.8833 - val_loss: 0.1456 - val_accuracy: 0.9500
# Epoch 42/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.2685 - accuracy: 0.8900 - val_loss: 0.1134 - val_accuracy: 0.9750
# Epoch 43/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.2030 - accuracy: 0.9133 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 44/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.2541 - accuracy: 0.8900 - val_loss: 0.1217 - val_accuracy: 0.9500
# Epoch 45/500
# 10/10 [==============================] - 4s 356ms/step - loss: 0.2308 - accuracy: 0.9167 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 46/500
# 10/10 [==============================] - 4s 358ms/step - loss: 0.1848 - accuracy: 0.9267 - val_loss: 0.1337 - val_accuracy: 0.9500
# Epoch 47/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1689 - accuracy: 0.9467 - val_loss: 0.1644 - val_accuracy: 0.9500
# Epoch 48/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1923 - accuracy: 0.9300 - val_loss: 0.1062 - val_accuracy: 0.9500
# Epoch 49/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.2011 - accuracy: 0.9300 - val_loss: 0.3009 - val_accuracy: 0.8750
# Epoch 50/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1792 - accuracy: 0.9200 - val_loss: 0.1328 - val_accuracy: 0.9250
# Epoch 51/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.2096 - accuracy: 0.9267 - val_loss: 0.0850 - val_accuracy: 0.9750
# Epoch 52/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1959 - accuracy: 0.9233 - val_loss: 0.2617 - val_accuracy: 0.9000
# Epoch 53/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.1493 - accuracy: 0.9500 - val_loss: 0.0641 - val_accuracy: 0.9750
# Epoch 54/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.2240 - accuracy: 0.9133 - val_loss: 0.1509 - val_accuracy: 0.9250
# Epoch 55/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.2114 - accuracy: 0.9233 - val_loss: 0.1945 - val_accuracy: 0.9250
# Epoch 56/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1590 - accuracy: 0.9500 - val_loss: 0.1282 - val_accuracy: 0.9500
# Epoch 57/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.2676 - accuracy: 0.9000 - val_loss: 0.2385 - val_accuracy: 0.9000
# Epoch 58/500
# 10/10 [==============================] - 4s 394ms/step - loss: 0.2316 - accuracy: 0.9000 - val_loss: 0.2087 - val_accuracy: 0.9250
# Epoch 59/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.2586 - accuracy: 0.9067 - val_loss: 0.1712 - val_accuracy: 0.9500
# Epoch 60/500
# 10/10 [==============================] - 4s 403ms/step - loss: 0.1768 - accuracy: 0.9233 - val_loss: 0.1232 - val_accuracy: 0.9750
# Epoch 61/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1626 - accuracy: 0.9433 - val_loss: 0.2408 - val_accuracy: 0.8750
# Epoch 62/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1780 - accuracy: 0.9333 - val_loss: 0.1007 - val_accuracy: 0.9500
# Epoch 63/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.1305 - accuracy: 0.9533 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 64/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1423 - accuracy: 0.9300 - val_loss: 0.0733 - val_accuracy: 0.9500
# Epoch 65/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.1545 - accuracy: 0.9367 - val_loss: 0.1558 - val_accuracy: 0.9250
# Epoch 66/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1583 - accuracy: 0.9400 - val_loss: 0.0751 - val_accuracy: 0.9750
# Epoch 67/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1902 - accuracy: 0.9433 - val_loss: 0.1398 - val_accuracy: 0.9750
# Epoch 68/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1353 - accuracy: 0.9567 - val_loss: 0.0725 - val_accuracy: 0.9750
# Epoch 69/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.1716 - accuracy: 0.9300 - val_loss: 0.0805 - val_accuracy: 0.9500
# Epoch 70/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.1827 - accuracy: 0.9400 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 71/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1445 - accuracy: 0.9433 - val_loss: 0.0633 - val_accuracy: 0.9750
# Epoch 72/500
# 10/10 [==============================] - 4s 383ms/step - loss: 0.1822 - accuracy: 0.9400 - val_loss: 0.3989 - val_accuracy: 0.8250
# Epoch 73/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.2471 - accuracy: 0.8933 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 74/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1768 - accuracy: 0.9333 - val_loss: 0.0611 - val_accuracy: 1.0000
# Epoch 75/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1885 - accuracy: 0.9300 - val_loss: 0.1664 - val_accuracy: 0.9250
# Epoch 76/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1967 - accuracy: 0.9233 - val_loss: 0.0586 - val_accuracy: 0.9750
# Epoch 77/500
# 10/10 [==============================] - 4s 389ms/step - loss: 0.1516 - accuracy: 0.9433 - val_loss: 0.0973 - val_accuracy: 0.9500
# Epoch 78/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1594 - accuracy: 0.9333 - val_loss: 0.0451 - val_accuracy: 0.9750
# Epoch 79/500
# 10/10 [==============================] - 4s 398ms/step - loss: 0.1445 - accuracy: 0.9400 - val_loss: 0.0885 - val_accuracy: 0.9500
# Epoch 80/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1392 - accuracy: 0.9500 - val_loss: 0.3592 - val_accuracy: 0.8750
# Epoch 81/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1887 - accuracy: 0.9233 - val_loss: 0.1389 - val_accuracy: 0.9500
# Epoch 82/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1830 - accuracy: 0.9333 - val_loss: 0.1019 - val_accuracy: 0.9750
# Epoch 83/500
# 10/10 [==============================] - 4s 397ms/step - loss: 0.1420 - accuracy: 0.9467 - val_loss: 0.0438 - val_accuracy: 0.9750
# Epoch 84/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.1397 - accuracy: 0.9433 - val_loss: 0.1089 - val_accuracy: 0.9250
# Epoch 85/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1879 - accuracy: 0.9433 - val_loss: 0.1399 - val_accuracy: 0.9500
# Epoch 86/500
# 10/10 [==============================] - 4s 409ms/step - loss: 0.1055 - accuracy: 0.9600 - val_loss: 0.2241 - val_accuracy: 0.9000
# Epoch 87/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.1374 - accuracy: 0.9500 - val_loss: 0.2266 - val_accuracy: 0.9000
# Epoch 88/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0938 - accuracy: 0.9667 - val_loss: 0.0911 - val_accuracy: 0.9500
# Epoch 89/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1669 - accuracy: 0.9400 - val_loss: 0.1625 - val_accuracy: 0.9250
# Epoch 90/500
# 10/10 [==============================] - 4s 395ms/step - loss: 0.1297 - accuracy: 0.9500 - val_loss: 0.0333 - val_accuracy: 0.9750
# Epoch 91/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1102 - accuracy: 0.9567 - val_loss: 0.1772 - val_accuracy: 0.9250
# Epoch 92/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1213 - accuracy: 0.9533 - val_loss: 0.1380 - val_accuracy: 0.9250
# Epoch 93/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0924 - accuracy: 0.9600 - val_loss: 0.1527 - val_accuracy: 0.9250
# Epoch 94/500
# 10/10 [==============================] - 4s 400ms/step - loss: 0.1025 - accuracy: 0.9533 - val_loss: 0.1128 - val_accuracy: 0.9250
# Epoch 95/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0952 - accuracy: 0.9733 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 96/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0987 - accuracy: 0.9633 - val_loss: 0.1280 - val_accuracy: 0.9500
# Epoch 97/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1446 - accuracy: 0.9500 - val_loss: 0.2622 - val_accuracy: 0.9000
# Epoch 98/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.1308 - accuracy: 0.9467 - val_loss: 0.0845 - val_accuracy: 0.9750
# Epoch 99/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1049 - accuracy: 0.9700 - val_loss: 0.1166 - val_accuracy: 0.9250
# Epoch 100/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0960 - accuracy: 0.9633 - val_loss: 0.1327 - val_accuracy: 0.9500
# Epoch 101/500
# 10/10 [==============================] - 4s 396ms/step - loss: 0.0964 - accuracy: 0.9533 - val_loss: 0.0835 - val_accuracy: 0.9750
# Epoch 102/500
# 10/10 [==============================] - 4s 396ms/step - loss: 0.0929 - accuracy: 0.9633 - val_loss: 0.1840 - val_accuracy: 0.9500
# Epoch 103/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0869 - accuracy: 0.9733 - val_loss: 0.1956 - val_accuracy: 0.9000
# Epoch 104/500
# 10/10 [==============================] - 4s 394ms/step - loss: 0.1141 - accuracy: 0.9567 - val_loss: 0.1626 - val_accuracy: 0.9250
# Epoch 105/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1132 - accuracy: 0.9600 - val_loss: 0.1668 - val_accuracy: 0.9500
# Epoch 106/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1033 - accuracy: 0.9600 - val_loss: 0.0433 - val_accuracy: 0.9750
# Epoch 107/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1377 - accuracy: 0.9600 - val_loss: 0.0345 - val_accuracy: 0.9750
# Epoch 108/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.1176 - accuracy: 0.9533 - val_loss: 0.1563 - val_accuracy: 0.9500
# Epoch 109/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1128 - accuracy: 0.9600 - val_loss: 0.1539 - val_accuracy: 0.9000
# Epoch 110/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1049 - accuracy: 0.9667 - val_loss: 0.0519 - val_accuracy: 0.9750
# Epoch 111/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.1437 - accuracy: 0.9467 - val_loss: 0.1824 - val_accuracy: 0.9000
# Epoch 112/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1104 - accuracy: 0.9500 - val_loss: 0.1477 - val_accuracy: 0.9500
# Epoch 113/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0878 - accuracy: 0.9500 - val_loss: 0.0806 - val_accuracy: 0.9500
# Epoch 114/500
# 10/10 [==============================] - 4s 420ms/step - loss: 0.0956 - accuracy: 0.9633 - val_loss: 0.0955 - val_accuracy: 0.9750
# Epoch 115/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.1781 - accuracy: 0.9400 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 116/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.1304 - accuracy: 0.9567 - val_loss: 0.0998 - val_accuracy: 0.9500
# Epoch 117/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.1289 - accuracy: 0.9533 - val_loss: 0.0429 - val_accuracy: 0.9750
# Epoch 118/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1437 - accuracy: 0.9400 - val_loss: 0.0426 - val_accuracy: 0.9750
# Epoch 119/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1364 - accuracy: 0.9567 - val_loss: 0.0784 - val_accuracy: 0.9500
# Epoch 120/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0797 - accuracy: 0.9733 - val_loss: 0.0562 - val_accuracy: 0.9500
# Epoch 121/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0648 - accuracy: 0.9767 - val_loss: 0.1057 - val_accuracy: 0.9750
# Epoch 122/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1072 - accuracy: 0.9600 - val_loss: 0.1129 - val_accuracy: 0.9500
# Epoch 123/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0880 - accuracy: 0.9733 - val_loss: 0.2328 - val_accuracy: 0.8500
# Epoch 124/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1258 - accuracy: 0.9500 - val_loss: 0.1509 - val_accuracy: 0.9000
# Epoch 125/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0905 - accuracy: 0.9567 - val_loss: 0.1893 - val_accuracy: 0.8750
# Epoch 126/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9833Reached 98% accuracy so cancelling training!
# 10/10 [==============================] - 4s 396ms/step - loss: 0.0571 - accuracy: 0.9833 - val_loss: 0.0918 - val_accuracy: 0.9750

# %% [markdown]
# ## Plotting Accuracy and Loss Functions

# %%
import matplotlib.pyplot as plt

# Plot the accuracy and loss functions
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn
y_pred = model.predict(validation_generator, 20)
print('Confusion Matrix')
y_predicted_labels = y_pred > 0.5

size = np.size(y_predicted_labels)
y_predicted_labels = y_predicted_labels.reshape(size, )

for i in range (1, 5):
  total = i * size // 4
  mid = 49
  start = mid-((total+1)//2)+1
  end = mid+((total+1)//2)
  cm = tf.math.confusion_matrix(labels=validation_generator.labels[start:end],predictions=y_predicted_labels[start:end])

  # Calculate accuracy
  cm_np = cm.numpy()
  conf_acc = (cm_np[0, 0] + cm_np[1, 1])/ np.sum(cm_np) * 100
  print("Accuracy for", str(total), "Test Data = ", conf_acc)

  # Plot the confusion matrix
  plt.figure(figsize = (10,7))
  seaborn.heatmap(cm, annot=True, fmt='d')
  plt.title("Confusion Matrix for " + str(total) + " Test Data")
  plt.xlabel('Predicted')
  plt.ylabel('Expected')
# Out:
# Confusion Matrix
# Accuracy for 25 Test Data =  40.0
# Accuracy for 50 Test Data =  40.816326530612244
# Accuracy for 75 Test Data =  45.33333333333333
# Accuracy for 100 Test Data =  51.515151515151516

# %% [markdown]
# ## Sample Example

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()
result = dict()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " - Sensitive")
    result[fn] = "Sensitive"
  else:
    print(fn + " - Non-sensitive")
    result[fn] = "Non-sensitive"

plt.figure(figsize=(20,20))
   
for i, fn in enumerate(uploaded.keys()):
  image = plt.imread(fn)  
  plt.subplot(5, 5, i+1)
  plt.axis("off")
  plt.imshow(image)
  ans = fn + ": " + result[fn]
  plt.title(ans)
# Out:
#      <input type="file" id="files-08312fa3-0f3e-4343-a174-d22703b65d24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08312fa3-0f3e-4343-a174-d22703b65d24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1 (1).gif to 1 (1).gif
# Saving 1 (1).jpeg to 1 (1) (1).jpeg
# Saving 1 (1).jpg to 1 (1).jpg
# Saving 1 (1).png to 1 (1).png
# Saving 1 (3).jpeg to 1 (3).jpeg
# [1.]
# 1 (1).gif - Sensitive
# [1.]
# 1 (1).jpeg - Sensitive
# [0.]
# 1 (1).jpg - Non-sensitive
# [1.]
# 1 (1).png - Sensitive
# [1.]
# 1 (3).jpeg - Sensitive
